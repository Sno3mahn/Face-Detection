# %%
import cv2

# %%
model=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
cap = cv2.VideoCapture(0)

# %%
def detect(face_param, i_param):
    pt1=(face[i][0],face[i][1])
    pt2=(face[i][0]+face[i][2],face[i][1]+face[i][3])
    det=cv2.rectangle(y,pt1,pt2,[255,0,0],2)
    cv2.imshow('pic', det)

# %%
while True:
    x, y = cap.read()
    face = model.detectMultiScale(y)
    face_num = len(face)
    if face_num ==0:
        cv2.imshow('pic', y)
        if cv2.waitKey(1) == 13:
            break
    else:
        for i in range(face_num):
            detect(face, i)
        if cv2.waitKey(1) == 13:
            break
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x557bbe4d3460) is not the object's thread (0x557bbea710d0).
# Cannot move to target thread (0x557bbe4d3460)
#
# QObject::moveToThread: Current thread (0x557bbe4d3460) is not the object's thread (0x557bbea710d0).
# Cannot move to target thread (0x557bbe4d3460)
#
# QObject::moveToThread: Current thread (0x557bbe4d3460) is not the object's thread (0x557bbea710d0).
# Cannot move to target thread (0x557bbe4d3460)
#
# QObject::moveToThread: Current thread (0x557bbe4d3460) is not the object's thread (0x557bbea710d0).
# Cannot move to target thread (0x557bbe4d3460)
#
# QObject::moveToThread: Current thread (0x557bbe4d3460) is not the object's thread (0x557bbea710d0).
# Cannot move to target thread (0x557bbe4d3460)
#
# QObject::moveToThread: Current thread (0x557bbe4d3460) is not the object's thread (0x557bbea710d0).
# Cannot move to target thread (0x557bbe4d3460)
#
# ...

# %%
cap.release()
